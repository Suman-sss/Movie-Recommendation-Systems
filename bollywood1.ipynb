# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('bollywood_full_1950-2019.csv')
data
# Out:
#                                    title_x    imdb_id  \
# 0                 Uri: The Surgical Strike  tt8291224
# 1                            Battalion 609  tt9472208
# 2     The Accidental Prime Minister (film)  tt6986710
# 3                          Why Cheat India  tt8108208
# 4                          Evening Shadows  tt6028796
# ...                                    ...        ...
# 4325                   Samadhi (1950 film)  tt0268614
# 4326                   Sangram (1950 film)  tt0244182
# 4327                    Sargam (1950 film)  tt0269826
# 4328              Sheesh Mahal (1950 film)  tt0243555
# 4329                   Meena Bazaar (film)  tt0213081
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
data.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
from imdb import IMDb
# create an instance of the IMDb class
ia = IMDb()

# %%
data.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release      object
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes          float64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
from imdb import IMDb
ia = IMDb()

# %%
data['imdb_id'] = data['imdb_id'].str.replace('tt', '0')
data['imdb_id']
# Out:
# 0       08291224
# 1       09472208
# 2       06986710
# 3       08108208
# 4       06028796
#           ...
# 4325    00268614
# 4326    00244182
# 4327    00269826
# 4328    00243555
# 4329    00213081
# Name: imdb_id, Length: 4330, dtype: object

# %%
new = data['actors'].str.split("|", n=1, expand=True)

# %%
data['actor_1_name'] = new[0]

# %%
data['actor_2'] = new[1]

# %%
new1 = data['actor_2'].str.split("|", n=1, expand=True)

# %%
data['actor_2_name'] = new1[0]

# %%
data['actor_3'] = new1[1]

# %%
new2 = data['actor_3'].str.split("|", n=1, expand=True)

# %%
data['actor_3_name'] = new2[0]

# %%
data
# Out:
#                                    title_x   imdb_id  \
# 0                 Uri: The Surgical Strike  08291224
# 1                            Battalion 609  09472208
# 2     The Accidental Prime Minister (film)  06986710
# 3                          Why Cheat India  08108208
# 4                          Evening Shadows  06028796
# ...                                    ...       ...
# 4325                   Samadhi (1950 film)  00268614
# 4326                   Sangram (1950 film)  00244182
# 4327                    Sargam (1950 film)  00269826
# 4328              Sheesh Mahal (1950 film)  00243555
# 4329                   Meena Bazaar (film)  00213081
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
data = data[['original_title', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'genres']]

# %%
data
# Out:
#                      original_title      actor_1_name  \
# 0          Uri: The Surgical Strike     Vicky Kaushal
# 1                     Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister       Anupam Kher
# 3                   Why Cheat India     Emraan Hashmi
# 4                   Evening Shadows  Mona Ambegaonkar
# ...                             ...               ...
# 4325                        Samadhi       Ashok Kumar
# 4326                        Sangram       Ashok Kumar
# 4327                         Sargam        Raj Kapoor
# 4328                   Sheesh Mahal       Sohrab Modi
# 4329                   Meena Bazaar               NaN
#
#                   actor_2_name           actor_3_name            genres
# 0                 Paresh Rawal            Mohit Raina  Action|Drama|War
# 1               Shoaib Ibrahim         Shrikant Kamat               War
# 2               Akshaye Khanna           Aahana Kumra   Biography|Drama
# ...

# %%
data['genres'] = data['genres'].str.replace('|', ' ')
# Out:
# C:\Users\SADIA SUMAN-PC\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.rename(columns={'original_title' : 'movie_title'}, inplace=True)
# Out:
# C:\Users\SADIA SUMAN-PC\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data
# Out:
#                         movie_title      actor_1_name  \
# 0          Uri: The Surgical Strike     Vicky Kaushal
# 1                     Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister       Anupam Kher
# 3                   Why Cheat India     Emraan Hashmi
# 4                   Evening Shadows  Mona Ambegaonkar
# ...                             ...               ...
# 4325                        Samadhi       Ashok Kumar
# 4326                        Sangram       Ashok Kumar
# 4327                         Sargam        Raj Kapoor
# 4328                   Sheesh Mahal       Sohrab Modi
# 4329                   Meena Bazaar               NaN
#
#                   actor_2_name           actor_3_name            genres
# 0                 Paresh Rawal            Mohit Raina  Action Drama War
# 1               Shoaib Ibrahim         Shrikant Kamat               War
# 2               Akshaye Khanna           Aahana Kumra   Biography Drama
# ...

# %%
data['movie_title'] = data['movie_title'].str.lower()
# Out:
# C:\Users\SADIA SUMAN-PC\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#                         movie_title      actor_1_name  \
# 0          uri: the surgical strike     Vicky Kaushal
# 1                     battalion 609       Vicky Ahuja
# 2     the accidental prime minister       Anupam Kher
# 3                   why cheat india     Emraan Hashmi
# 4                   evening shadows  Mona Ambegaonkar
# ...                             ...               ...
# 4325                        samadhi       Ashok Kumar
# 4326                        sangram       Ashok Kumar
# 4327                         sargam        Raj Kapoor
# 4328                   sheesh mahal       Sohrab Modi
# 4329                   meena bazaar               NaN
#
#                   actor_2_name           actor_3_name            genres
# 0                 Paresh Rawal            Mohit Raina  Action Drama War
# 1               Shoaib Ibrahim         Shrikant Kamat               War
# 2               Akshaye Khanna           Aahana Kumra   Biography Drama
# ...

# %%
data['comb'] = data['actor_1_name'] + ' ' + data['actor_2_name'] + ' '+ data['actor_3_name'] + ' ' + data['genres']
# Out:
# C:\Users\SADIA SUMAN-PC\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#                         movie_title      actor_1_name  \
# 0          uri: the surgical strike     Vicky Kaushal
# 1                     battalion 609       Vicky Ahuja
# 2     the accidental prime minister       Anupam Kher
# 3                   why cheat india     Emraan Hashmi
# 4                   evening shadows  Mona Ambegaonkar
# ...                             ...               ...
# 4325                        samadhi       Ashok Kumar
# 4326                        sangram       Ashok Kumar
# 4327                         sargam        Raj Kapoor
# 4328                   sheesh mahal       Sohrab Modi
# 4329                   meena bazaar               NaN
#
#                   actor_2_name           actor_3_name            genres  \
# 0                 Paresh Rawal            Mohit Raina  Action Drama War
# 1               Shoaib Ibrahim         Shrikant Kamat               War
# 2               Akshaye Khanna           Aahana Kumra   Biography Drama
# ...

# %%
data.isna().sum()
# Out:
# movie_title      0
# actor_1_name    10
# actor_2_name    10
# actor_3_name    56
# genres           0
# comb            56
# dtype: int64

# %%
data = data.replace(np.nan, 'unknown')

# %%
data
# Out:
#                         movie_title      actor_1_name  \
# 0          uri: the surgical strike     Vicky Kaushal
# 1                     battalion 609       Vicky Ahuja
# 2     the accidental prime minister       Anupam Kher
# 3                   why cheat india     Emraan Hashmi
# 4                   evening shadows  Mona Ambegaonkar
# ...                             ...               ...
# 4325                        samadhi       Ashok Kumar
# 4326                        sangram       Ashok Kumar
# 4327                         sargam        Raj Kapoor
# 4328                   sheesh mahal       Sohrab Modi
# 4329                   meena bazaar           unknown
#
#                   actor_2_name           actor_3_name            genres  \
# 0                 Paresh Rawal            Mohit Raina  Action Drama War
# 1               Shoaib Ibrahim         Shrikant Kamat               War
# 2               Akshaye Khanna           Aahana Kumra   Biography Drama
# ...

# %%
old = pd.read_csv('main_data.csv')
old
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6011    Joseph Kosinski       Tom Cruise      Miles Teller
# 6012      Joel Crawford     Nicolas Cage        Emma Stone
# 6013        Liesl Tommy  Jennifer Hudson   Forest Whitaker
# 6014       Ridley Scott       Matt Damon       Adam Driver
# 6015    Paul Greengrass        Tom Hanks     Helena Zengel
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
old = old.drop(columns=['Genre'])
old
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6011    Joseph Kosinski       Tom Cruise      Miles Teller
# 6012      Joel Crawford     Nicolas Cage        Emma Stone
# 6013        Liesl Tommy  Jennifer Hudson   Forest Whitaker
# 6014       Ridley Scott       Matt Damon       Adam Driver
# 6015    Paul Greengrass        Tom Hanks     Helena Zengel
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
old = old.replace(np.nan, 'unknown')
old
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6011    Joseph Kosinski       Tom Cruise      Miles Teller
# 6012      Joel Crawford     Nicolas Cage        Emma Stone
# 6013        Liesl Tommy  Jennifer Hudson   Forest Whitaker
# 6014       Ridley Scott       Matt Damon       Adam Driver
# 6015    Paul Greengrass        Tom Hanks     Helena Zengel
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
final = old.append(data, ignore_index=True)
final
# Out:
#            director_name     actor_1_name      actor_2_name  \
# 0          James Cameron      CCH Pounder  Joel David Moore
# 1         Gore Verbinski      Johnny Depp     Orlando Bloom
# 2             Sam Mendes  Christoph Waltz      Rory Kinnear
# 3      Christopher Nolan        Tom Hardy    Christian Bale
# 4            Doug Walker      Doug Walker        Rob Walker
# ...                  ...              ...               ...
# 10341                NaN      Ashok Kumar    Nalini Jaywant
# 10342                NaN      Ashok Kumar    Nalini Jaywant
# 10343                NaN       Raj Kapoor            Rehana
# 10344                NaN      Sohrab Modi       Naseem Banu
# 10345                NaN          unknown           unknown
#
#                actor_3_name                           genres  \
# 0                 Wes Studi  Action Adventure Fantasy Sci-Fi
# 1            Jack Davenport         Action Adventure Fantasy
# ...

# %%
final = final.replace(np.nan, 'unknown')
final
# Out:
#            director_name     actor_1_name      actor_2_name  \
# 0          James Cameron      CCH Pounder  Joel David Moore
# 1         Gore Verbinski      Johnny Depp     Orlando Bloom
# 2             Sam Mendes  Christoph Waltz      Rory Kinnear
# 3      Christopher Nolan        Tom Hardy    Christian Bale
# 4            Doug Walker      Doug Walker        Rob Walker
# ...                  ...              ...               ...
# 10341            unknown      Ashok Kumar    Nalini Jaywant
# 10342            unknown      Ashok Kumar    Nalini Jaywant
# 10343            unknown       Raj Kapoor            Rehana
# 10344            unknown      Sohrab Modi       Naseem Banu
# 10345            unknown          unknown           unknown
#
#                actor_3_name                           genres  \
# 0                 Wes Studi  Action Adventure Fantasy Sci-Fi
# 1            Jack Davenport         Action Adventure Fantasy
# ...

# %%
final.to_csv('main_data1.csv')
